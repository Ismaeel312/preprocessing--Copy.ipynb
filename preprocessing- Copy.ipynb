# %%
import pandas as pd 
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data.csv")

# %%
df.columns
# Out:
# Index(['Ranking', 'Username', 'Subscribers', 'Uploads', 'Views', 'Country'], dtype='object')

# %%
df.head(4)
# Out:
#    Ranking                  Username Subscribers Uploads            Views  \
# 0      1.0                   MrBeast        336M     838   66,853,633,536
# 1      2.0                  T-Series        281M  22,313  277,242,795,553
# 2      3.0  Cocomelon-Nursery Rhymes        186M    1370  194,361,752,276
# 3      4.0            Youtube Movies        185M       0                0
#
#   Country
# 0      US
# 1      IN
# 2      US
# 3     NaN

# %%
df.shape
# Out:
# (101, 6)

# %%
df.tail(2)
# Out:
#      Ranking Username Subscribers Uploads           Views Country
# 99     100.0    Zhong       45.5M   1,861  17,998,163,730      US
# 100      NaN      NaN         NaN     NaN             NaN     NaN

# %%
df.sample(3)
# Out:
#     Ranking               Username Subscribers  Uploads            Views  \
# 1       2.0               T-Series        281M   22,313  277,242,795,553
# 69     70.0  ABS-CBN Entertainment       50.8M  234,889   56,273,184,883
# 56     57.0              PANDA BOL       55.9M    1,143   25,243,008,251
#
#    Country
# 1       IN
# 69      PH
# 56      IT

# %%
df.column s
# Out:
# Index(['Ranking', 'Username', 'Subscribers', 'Uploads', 'Views', 'Country'], dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of      Ranking                  Username Subscribers  Uploads            Views  \
# 0        1.0                   MrBeast        336M      838   66,853,633,536
# 1        2.0                  T-Series        281M   22,313  277,242,795,553
# 2        3.0  Cocomelon-Nursery Rhymes        186M     1370  194,361,752,276
# 3        4.0            Youtube Movies        185M        0                0
# 4        5.0                 Set India        180M  148,727  172,709,029,653
# ..       ...                       ...         ...      ...              ...
# 96      97.0                Voce Sabia         46M    1,714    8,180,068,059
# 97      98.0                Katy Perry       45.6M      170   27,616,850,074
# 98      99.0             Speed Records       45.5M   11,880   30,587,436,800
# 99     100.0                     Zhong       45.5M    1,861   17,998,163,730
# 100      NaN                       NaN         NaN      NaN              NaN
#
#     Country
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Ranking                  Username Subscribers  Uploads            Views  \
# 0        1.0                   MrBeast        336M      838   66,853,633,536
# 1        2.0                  T-Series        281M   22,313  277,242,795,553
# 2        3.0  Cocomelon-Nursery Rhymes        186M     1370  194,361,752,276
# 3        4.0            Youtube Movies        185M        0                0
# 4        5.0                 Set India        180M  148,727  172,709,029,653
# ..       ...                       ...         ...      ...              ...
# 96      97.0                Voce Sabia         46M    1,714    8,180,068,059
# 97      98.0                Katy Perry       45.6M      170   27,616,850,074
# 98      99.0             Speed Records       45.5M   11,880   30,587,436,800
# 99     100.0                     Zhong       45.5M    1,861   17,998,163,730
# 100      NaN                       NaN         NaN      NaN              NaN
#
# ...

# %%
a = df.describe(include="all")

# %%
a.loc[["top","mean"]]
# Out:
#       Ranking Username Subscribers Uploads Views Country
# top       NaN  MrBeast       62.9M       0     0      IN
# mean     50.5      NaN         NaN     NaN   NaN     NaN

# %%
a.iloc[[9,1,3]]
# Out:
#         Ranking Username Subscribers Uploads Views Country
# 75%       75.25      NaN         NaN     NaN   NaN     NaN
# unique      NaN      100          83      97    97      23
# freq        NaN        1           4       4     4      28

# %%
pd.set_option("display.max_rows" ,None)
pd.set_option("display.max_columns",None)
df[["Ranking","Subscribers"]]
# Out:
#      Ranking Subscribers
# 0        1.0        336M
# 1        2.0        281M
# 2        3.0        186M
# 3        4.0        185M
# 4        5.0        180M
# 5        6.0        129M
# 6        7.0        128M
# 7        8.0        124M
# 8        9.0        121M
# 9       10.0        112M
# 10      11.0        110M
# 11      12.0        106M
# 12      13.0        102M
# 13      14.0        101M
# 14      15.0       97.7M
# 15      16.0       95.4M
# 16      17.0       94.3M
# 17      18.0       92.9M
# 18      19.0       86.2M
# 19      20.0       81.1M
# 20      21.0       79.4M
# 21      22.0       79.3M
# 22      23.0       77.6M
# 23      24.0       76.2M
# 24      25.0       74.7M
# 25      26.0       74.4M
# 26      27.0       73.3M
# 27      28.0       72.6M
# 28      29.0       71.7M
# 29      30.0       71.5M
# 30      31.0         71M
# 31      32.0       70.3M
# 32      33.0         70M
# 33      34.0       69.4M
# 34      35.0       68.7M
# 35      36.0       68.3M
# ...

# %%
df["Subscribers"]
# Out:
# 0       336M
# 1       281M
# 2       186M
# 3       185M
# 4       180M
# 5       129M
# 6       128M
# 7       124M
# 8       121M
# 9       112M
# 10      110M
# 11      106M
# 12      102M
# 13      101M
# 14     97.7M
# 15     95.4M
# 16     94.3M
# 17     92.9M
# 18     86.2M
# 19     81.1M
# 20     79.4M
# 21     79.3M
# 22     77.6M
# 23     76.2M
# 24     74.7M
# 25     74.4M
# 26     73.3M
# 27     72.6M
# 28     71.7M
# 29     71.5M
# 30       71M
# 31     70.3M
# 32       70M
# 33     69.4M
# 34     68.7M
# 35     68.3M
# 36     67.5M
# 37     67.1M
# 38     66.8M
# 39     63.7M
# 40     63.4M
# 41     62.9M
# 42     62.9M
# 43     62.9M
# 44     62.9M
# 45     62.8M
# 46     60.8M
# 47     60.6M
# 48     60.4M
# 49       60M
# 50     59.9M
# 51     59.3M
# 52     57.6M
# 53     57.5M
# 54     56.5M
# 55     56.3M
# 56     55.9M
# 57     55.9M
# 58     55.6M
# 59     55.1M
# 60     53.9M
# 61     53.9M
# 62     53.6M
# 63     53.4M
# 64     53.2M
# 65     52.5M
# ...

# %%
print(df["Ranking"])
# Out:
# 0        1.0
# 1        2.0
# 2        3.0
# 3        4.0
# 4        5.0
# 5        6.0
# 6        7.0
# 7        8.0
# 8        9.0
# 9       10.0
# 10      11.0
# 11      12.0
# 12      13.0
# 13      14.0
# 14      15.0
# 15      16.0
# 16      17.0
# 17      18.0
# 18      19.0
# 19      20.0
# 20      21.0
# 21      22.0
# 22      23.0
# 23      24.0
# 24      25.0
# 25      26.0
# 26      27.0
# 27      28.0
# 28      29.0
# 29      30.0
# 30      31.0
# 31      32.0
# 32      33.0
# 33      34.0
# 34      35.0
# 35      36.0
# 36      37.0
# 37      38.0
# 38      39.0
# 39      40.0
# 40      41.0
# 41      42.0
# 42      43.0
# 43      44.0
# 44      45.0
# 45      46.0
# 46      47.0
# 47      48.0
# 48      49.0
# 49      50.0
# 50      51.0
# 51      52.0
# 52      53.0
# 53      54.0
# 54      55.0
# 55      56.0
# 56      57.0
# 57      58.0
# 58      59.0
# 59      60.0
# 60      61.0
# 61      62.0
# 62      63.0
# 63      64.0
# 64      65.0
# 65      66.0
# ...

# %%
df['Ranking'].mean()
# Out:
# 50.5

# %%
df['Ranking'].mode()
# Out:
# 0       1.0
# 1       2.0
# 2       3.0
# 3       4.0
# 4       5.0
# 5       6.0
# 6       7.0
# 7       8.0
# 8       9.0
# 9      10.0
# 10     11.0
# 11     12.0
# 12     13.0
# 13     14.0
# 14     15.0
# 15     16.0
# 16     17.0
# 17     18.0
# 18     19.0
# 19     20.0
# 20     21.0
# 21     22.0
# 22     23.0
# 23     24.0
# 24     25.0
# 25     26.0
# 26     27.0
# 27     28.0
# 28     29.0
# 29     30.0
# 30     31.0
# 31     32.0
# 32     33.0
# 33     34.0
# 34     35.0
# 35     36.0
# 36     37.0
# 37     38.0
# 38     39.0
# 39     40.0
# 40     41.0
# 41     42.0
# 42     43.0
# 43     44.0
# 44     45.0
# 45     46.0
# 46     47.0
# 47     48.0
# 48     49.0
# 49     50.0
# 50     51.0
# 51     52.0
# 52     53.0
# 53     54.0
# 54     55.0
# 55     56.0
# 56     57.0
# 57     58.0
# 58     59.0
# 59     60.0
# 60     61.0
# 61     62.0
# 62     63.0
# 63     64.0
# 64     65.0
# 65     66.0
# 66     67.0
# 67     68.0
# 68     69.0
# 69     70.0
# 70     71.0
# ...

# %%
df['Ranking'].median()
# Out:
# 50.5

# %%
df["Ranking"].value_counts()
# Out:
# Ranking
# 1.0      1
# 64.0     1
# 74.0     1
# 73.0     1
# 72.0     1
# 71.0     1
# 70.0     1
# 69.0     1
# 68.0     1
# 67.0     1
# 66.0     1
# 65.0     1
# 63.0     1
# 2.0      1
# 62.0     1
# 61.0     1
# 60.0     1
# 59.0     1
# 58.0     1
# 57.0     1
# 56.0     1
# 55.0     1
# 54.0     1
# 53.0     1
# 75.0     1
# 76.0     1
# 77.0     1
# 78.0     1
# 99.0     1
# 98.0     1
# 97.0     1
# 96.0     1
# 95.0     1
# 94.0     1
# 93.0     1
# 92.0     1
# 91.0     1
# 90.0     1
# 89.0     1
# 88.0     1
# 87.0     1
# 86.0     1
# 85.0     1
# 84.0     1
# 83.0     1
# 82.0     1
# 81.0     1
# 80.0     1
# 79.0     1
# 52.0     1
# 51.0     1
# 50.0     1
# 25.0     1
# 23.0     1
# 22.0     1
# 21.0     1
# 20.0     1
# 19.0     1
# 18.0     1
# 17.0     1
# 16.0     1
# 15.0     1
# 14.0     1
# 13.0     1
# 12.0     1
# 11.0     1
# 10.0     1
# 9.0      1
# 8.0      1
# 7.0      1
# 6.0      1
# 5.0      1
# 4.0      1
# 3.0      1
# 24.0     1
# 26.0     1
# ...

# %%
df['Ranking'].value_counts().plot(kind="bar",title="Youtubers",color="red")
# Out:
# <Axes: title={'center': 'Youtubers'}, xlabel='Ranking'>

# %%
df['Ranking'].value_counts().plot(kind="pie",title="Youtuber",color="blue")
# Out:
# <Axes: title={'center': 'Youtuber'}, ylabel='count'>

# %%
df.isnull().sum()
# Out:
# Ranking        1
# Username       1
# Subscribers    1
# Uploads        1
# Views          1
# Country        7
# dtype: int64

# %%
df[df["Username"].isnull()]
# Out:
#      Ranking Username Subscribers Uploads Views Country
# 100      NaN      NaN         NaN     NaN   NaN     NaN

# %%
df.groupby("Ranking").describe()
# Out:
#         Username                                              Subscribers  \
#            count unique                              top freq       count
# Ranking
# 1.0            1      1                          MrBeast    1           1
# 2.0            1      1                         T-Series    1           1
# 3.0            1      1         Cocomelon-Nursery Rhymes    1           1
# 4.0            1      1                   Youtube Movies    1           1
# 5.0            1      1                        Set India    1           1
# 6.0            1      1                      Vlad & Niki    1           1
# 7.0            1      1                  Kids Diana Show    1           1
# 8.0            1      1                      Like Nastya    1           1
# 9.0            1      1                            Music    1           1
# 10.0           1      1                Zee Music Company    1           1
# ...

# %%
df.to_csv("data2.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.to_csv("data2.csv")
#
# NameError: name 'df' is not defined
